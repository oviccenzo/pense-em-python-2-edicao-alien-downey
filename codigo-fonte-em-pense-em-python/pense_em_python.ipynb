# %% [markdown]
# #Capitulo 1: jornada do programa

# %% [markdown]
# ##1.3 -primeiro programa

# %%
print("hello world")
# Out:
# hello world

# %%
'hello world!'
# Out:
# 'hello world!'

# %% [markdown]
# ##1.4 operadores aritmeticos

# %%
40 + 2
# Out:
# 42

# %%
43-2
# Out:
# 41

# %%
6*7
# Out:
# 42

# %%
6**2+6
# Out:
# 42

# %%
6 ^ 2
# Out:
# 4
