# %% [markdown]
# <a href="https://colab.research.google.com/github/oviccenzo/pense-em-python-2-edicao-alien-downey/blob/main/pense_em_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Capitulo 1: jornada do programa

# %% [markdown]
# ##1.3 -primeiro programa

# %%
print("hello world")
# Out:
# hello world

# %%
'hello world!'
# Out:
# 'hello world!'

# %% [markdown]
# ##1.4 operadores aritmeticos

# %%
40 + 2
# Out:
# 42

# %%
43-2
# Out:
# 41

# %%
6*7
# Out:
# 42

# %%
6**2+6
# Out:
# 42

# %%
6 ^ 2
# Out:
# 4

# %% [markdown]
# ##1.5 - valores e tipos

# %%
type(2)
# Out:
# int

# %%
type(42.0)
# Out:
# float

# %%
type('hello world!')
# Out:
# str

# %%
type('2')
# Out:
# str

# %%
type('42.0')
# Out:
# str

# %%
type('hello world!')
# Out:
# str

# %%
1,000,000
# Out:
# (1, 0, 0)

# %% [markdown]
# # Capitulo 2: variaveis e tipos

# %% [markdown]
# # Capitulo 3: funcoes

# %% [markdown]
# #Capitulo 4 : estudos de caso projeto de interface

# %% [markdown]
# # Capitulo 5: condicionais e recursividade
